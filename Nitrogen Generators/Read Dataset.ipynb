# %%
import pandas as pd

# %%
df = pd.read_csv('023083_Maxi.csv')

# %%
df
# Out:
#                        TIMESTAMP  Actuation Status  Alarm contact  \
# 0       2023-09-29T21:53:46.226Z               NaN            NaN
# 1       2023-09-29T21:53:45.704Z               NaN            1.0
# 2           2023-09-29T21:50:00Z               NaN            NaN
# 3       2023-09-29T21:44:44.752Z               NaN            NaN
# 4       2023-09-29T21:44:38.850Z               NaN            NaN
# ...                          ...               ...            ...
# 349550  2023-07-31T22:00:42.889Z               NaN            NaN
# 349551  2023-07-31T22:00:41.868Z               NaN            NaN
# 349552  2023-07-31T22:00:41.465Z               NaN            1.0
# 349553  2023-07-31T22:00:40.727Z               NaN            NaN
# 349554      2023-07-31T22:00:00Z               NaN            NaN
#
#        Alarm contact text  Autorestart Autorestart text  CMS air pressure  \
# 0                     NaN          NaN              NaN               NaN
# ...
