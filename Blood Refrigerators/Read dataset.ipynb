# %%
import pandas as pd

# %%
df = pd.read_csv('dataset_bin_84950_P0.csv')

# %%
df
# Out:
#                      timestamp  Door opening daily counter  \
# 0      2022-12-30 23:00:00.000                         1.0
# 1      2022-12-30 22:56:15.051                         1.0
# 2      2022-12-30 22:52:37.247                         1.0
# 3      2022-12-30 22:52:36.813                         1.0
# 4      2022-12-30 22:48:04.462                         1.0
# ...                        ...                         ...
# 38376  2022-11-01 03:00:00.000                         0.0
# 38377  2022-11-01 02:00:00.000                         0.0
# 38378  2022-11-01 01:00:00.000                         0.0
# 38379  2022-11-01 00:00:00.000                         0.0
# 38380  2022-10-31 23:00:00.000                         0.0
#
#        Power consumption month [KWH]  Transmitted Bytes  \
# 0                          20.523001           261605.0
# 1                          20.523001           261605.0
# 2                          20.523001           261605.0
# ...
